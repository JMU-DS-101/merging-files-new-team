# %% [markdown]
# # Lesson 1: The Team Page
#
# ## Overview
#
# In this lesson, we are going to build our team page. Not only does this complete the first phase of the project. It will get you a better understanding of the collaborative workflow.
#
# By the end of this lesson you will have:
# - Built a team page by editing HTML directly
# - Discovered why that approach breaks down
# - Used Python Jupyter to generate the same page automatically from a spreadsheet
# - Understood why separating *data* from *presentation* is a core principle of computing
# - Pushed content to the web and updated the first part of your project
#
# This lesson introduces two ideas that will recur throughout the whole unit:
#
# 1. **Variables** — giving the computer a name for a piece of information so it can reuse it
# 2. **Input / Output (I/O)** — the computer reads something in, does work, writes something out

# %% [markdown]
# ---
#
# ## Part 1 — What is a Website?
#
# Every webpage you visit in a browser is built from a text file called **HTML** (HyperText Markup Language). HTML uses *tags* — words wrapped in angle brackets — to describe what each piece of content is.
#
# ```html
# <h3>Alex Rivera</h3>         ← a heading
# <p>Digital Studies</p>       ← a paragraph
# <a href="...">GitHub</a>    ← a clickable link
# ```
#
# A browser reads those tags and turns them into the page you see. The *content* (names, text, links) and the *instructions* (tags) are mixed together in the same file.
#
# Generally, HTML handles the structure of the page. As you will learn later, CSS controls styling and JavaScript controls the interactivity. These three languages, HTML, CSS, and JS are the foundation of modern web coding.
#
# Open the file `team_static.html` in your file explorer. It should appear in the **Explorer panel** on the left. You can also right-click it and choose **Open with → Browser Preview** (or simply open it in a browser) to see what it looks like before you've filled anything in.

# %% [markdown]
# ---
#
# ## Part 2 — Task A: Fill In Your Team
#
# **Each person edits only their own assigned member card.** Do not touch any other card.
#
# You will use the branch workflow from [Introduction to GitHub](https://github.com/skills/introduction-to-github) that you have already completed: create a branch, make your changes, and open a Pull Request to merge back into `main`.
#
# ### Create your branch
#
# 1. Click the branch name **main** in the Codespaces status bar (bottom left of the window).
# 2. Select **Create new branch…**
# 3. Name it `firstname-card` using your first name — e.g., `alex-card`.
# 4. Press **Enter** — Codespaces switches to your new branch automatically.
#
# ✅ You should see your branch name (not `main`) in the status bar.
#
# ### Open the file
#
# 1. Open **Explorer** (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">).
# 2. Double-click `team_static.html` (<img src="../lesson_assets/images/vscode/file-text.svg" alt="File icon" width="14">) to open it.
#
# ✅ You should see the file's HTML in the editor.
#
# ### Edit your card
#
# Inside the file you will see five card blocks, each with placeholder comments:
#
# ```html
# <!-- FULL NAME e.g. Alex Rivera -->
# <!-- MAJOR e.g. Digital Studies -->
# <!-- ROLE e.g. Data Collection -->
# <!-- GITHUB URL -->
# <!-- INITIALS e.g. AR -->
# ```
#
# Replace **only** the comment for your team member number. Delete the whole comment — including the `<!--` and `-->` — and type the value directly.
#
# ```html
# <!-- Before -->
# <h3><!-- FULL NAME e.g. Alex Rivera --></h3>
#
# <!-- After -->
# <h3>Alex Rivera</h3>
# ```
#
# ### Save the file
#
# <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> `Ctrl+S` | <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> `Cmd+S`
#
# ✅ Refresh your browser preview. You should see your card filled in.

# %% [markdown]
# ---
#
# ## Part 2.2 — Update Your Changes
#
# After saving your edit, commit it on your branch and open a Pull Request so each person's work merges into `main` cleanly — without overwriting anyone else's card. This is the same workflow from [Introduction to GitHub](https://github.com/skills/introduction-to-github).
#
# ### Commit on your branch
#
# 1. Open **Source Control** (<img src="../lesson_assets/images/vscode/source-control.svg" alt="Source Control icon" width="14">).
# 2. Confirm only `team_static.html` appears under **Changes**.
# 3. Click `+` next to **Changes** to stage all changes.
# 4. Enter commit message: `Updated about card`.
# 5. Click **Commit**.
#
# ### Push your branch to GitHub
#
# 1. Click **Publish Branch** at the top of Source Control (or in the status bar).
#
# ✅ Your branch is now on GitHub.
#
# ### Open a Pull Request
#
# 1. Go to your team's repository on **GitHub.com**.
# 2. You should see a **"Compare & pull request"** banner for your branch — click it.
# 3. Confirm `base: main` ← `compare: your-branch-name`.
# 4. Add a short title, e.g., `Add Alex Rivera card`.
# 5. Click **Create pull request**.
#
# ✅ Your PR is open and visible to the team.
#
# ### Merge and sync
#
# 1. As a team, merge each PR into `main` one at a time.
#    - If a merge conflict appears, follow the resolution steps from [Resolving Merge Conflicts](https://github.com/skills/resolve-merge-conflicts).
# 2. After all PRs are merged, switch back to **main** in your Codespace:
#    - Click your branch name in the status bar → select **main**.
# 3. Click **Sync Changes** to pull the latest version of `main`.
#
# ✅ Everyone should now see the same updated page on `main`.
#
# ### Important
#
# - Work only on your own branch — never commit directly to `main`.
# - Edit only your assigned member card.
# - If a conflict appears during a PR merge, resolve it as a team before merging the next PR.

# %% [markdown]
# ---
#
# ## Part 3 — Sort Alphabetically
#
# Imagine your team wants cards listed alphabetically by **last name**.
#
# Choose **one person** to do this step so the group does not create conflicting edits.
#
# ### Reorder the cards in `team_static.html`
#
# 1. Open `team_static.html` in **Explorer** (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">).
# 2. Find a full team-member block (from the comment line before it down to its closing `</div>`).
# 3. Select the whole block.
# 4. Move blocks into alphabetical order by last name using cut and paste:
#    - <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> **Cut:** `Ctrl+X` | **Paste:** `Ctrl+V`
#    - <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> **Cut:** `Cmd+X` | **Paste:** `Cmd+V`
# 5. Save the file: <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> `Ctrl+S` | <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> `Cmd+S`
# 6. **Do not commit** these changes.
#
# ✅ You should now see cards in alphabetical order in the preview.
#
# **Quick reflection:**
#
# - Was this frustrating to do?
# - If your group had 30 members, how long would this take?
# - What would happen if you later wanted to group by major instead?
#
# ### Part 3.1 — Discard These Changes
#
# You are discarding on purpose so this file does not cause merge conflicts.
#
# 1. Open **Source Control** (<img src="../lesson_assets/images/vscode/source-control.svg" alt="Source Control icon" width="14">).
# 2. Find `team_static.html` in the **Changes** files list.
# 3. Click the **Discard Changes** icon (<img src="../lesson_assets/images/vscode/discard.svg" alt="Discard Changes icon" width="14">) next to the file.
# 4. Confirm **Yes** when prompted.
#
# ✅ `team_static.html` returns to the last committed version.

# %% [markdown]
# ---
#
# ## Part 4 — The Problem with Hardcoding
#
# What you just did is called **hardcoding** — writing specific values directly into a file that is supposed to be *structure*, not *content*.
#
# Here's the core problem:
#
# > When data and presentation are mixed together, every change to the data requires a human to find and edit code.
#
# In a small team this is annoying. At real scale — a company website with thousands of employees, a university directory, a news article database — it becomes impossible.
#
# The solution is **separation of concerns**: keep the data in one place, keep the presentation instructions in another, and write code that connects them.
#
# You already use this pattern every day without thinking about it. A Google Sheets spreadsheet is *data*. The chart Google Sheets draws from it is *presentation*. If you add a row to the spreadsheet, the chart updates automatically. You didn't touch the chart.
#
# That is exactly what we are going to do with your team page.

# %% [markdown]
# ---
#
# ## Part 6 — Data in a Spreadsheet
#
# **What is a CSV, and why use it?**
#
# A **CSV** (Comma-Separated Values) file is the simplest possible spreadsheet format. Think of it as the spreadsheet version of a **.txt** file. It does not allow fancy formatting like an Excel file (.xls) or a Google Sheet (.gsheet), but since it is just raw data it is highly compatible. Pretty much any spreadsheet software can open CSV files, which makes them easy to share and process with code.
#
# ### Before you start (30-second check)
#
# - Open **Explorer** (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">) in your Codespace (left sidebar).
# - Open the `lesson_1_the_team/data` folder (<img src="../lesson_assets/images/vscode/folder.svg" alt="Folder icon" width="14">).
# - Confirm you can see `team_template.csv` (<img src="../lesson_assets/images/vscode/table.svg" alt="CSV/spreadsheet icon" width="14">).
#
# If you can see that file, continue.
#
# **Your task:**
#
# 1. Copy `team_template.csv` in the `data` folder and rename it `team.csv`.
#    - This is a common data workflow practice: start from a known-good template so everyone uses the same column structure. It can feel tedious, but it prevents formatting mistakes and gives you a clean backup if something goes wrong.
#    <ol type="a">
#      <li>Select <code>team_template.csv</code> in Explorer (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">).</li>
#      <li>Copy the file:<br><img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> Right-click → <strong>Copy</strong> or <strong>Ctrl+C</strong><br><img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> Control-click (or two-finger click) → <strong>Copy</strong> or <strong>Cmd+C</strong></li>
#      <li>Paste in the same <code>data</code> folder (<img src="../lesson_assets/images/vscode/folder.svg" alt="Folder icon" width="14">):<br><img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> Right-click empty space in folder → <strong>Paste</strong> or <strong>Ctrl+V</strong><br><img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> Control-click empty space in folder → <strong>Paste</strong> or <strong>Cmd+V</strong></li>
#      <li>Rename the copied file to <code>team.csv</code>:<br><img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> Right-click copied file → <strong>Rename</strong> or <strong>F2</strong><br><img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> Control-click copied file → <strong>Rename</strong> or <strong>Return</strong></li>
#    </ol>
#    - ✅ You should now see **both** files in `data`: `team_template.csv` and `team.csv` (with CSV/spreadsheet icons like <img src="../lesson_assets/images/vscode/table.svg" alt="CSV/spreadsheet icon" width="14">).
# 2. Open `data/team.csv` and fill in one row per team member.
#    - Open file: double-click `team.csv` in Explorer (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">).
#    - Edit value: click a cell and type, then press Enter.
#    - Save file: <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> <strong>Ctrl+S</strong> | <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> <strong>Cmd+S</strong>
# 3. Replace placeholder values (`member1` through `member5`) with real information, including each person’s actual role (e.g. Data Collection, Visualization, Writing).
# 4. Leave the `headshot` column blank if you do not have a photo URL (<img src="../lesson_assets/images/vscode/file-media.svg" alt="Image/media icon" width="14">).
#
# ### If CSV editing does not work
#
# Install **Simple CSV Editor** (estivo):
# 1. Open **Extensions** (<img src="../lesson_assets/images/vscode/extensions.svg" alt="Extensions icon" width="14">) in your Codespace (left sidebar).
# 2. Search `Simple CSV Editor` (<img src="../lesson_assets/images/vscode/search.svg" alt="Search icon" width="14">).
#    1. <img src="./images/simple_csv_editor.png" alt="simple_csv_editor" width="50%">
# 3. Click **Install**.
# 4. Close and reopen `team.csv`.
#
# Don't worry about row order; the script will sort names automatically.
#
# > **Important:** Any row where `role` is still `member1`, `member2`, etc. will be skipped when the team page is generated. Only fully completed rows appear on the site.

# %% [markdown]
# ---
#
# ## Part 7 — What is a Variable?
#
# Before we run any code, one concept to understand: a **variable** is just a label the computer uses to remember a value.
#
# ```python
# name = "Alex Rivera"    # the label is 'name'; the value is 'Alex Rivera'
# major = "Digital Studies"
# ```
#
# You've been doing this in HTML too — just without Python syntax. The difference is that in Python, variables can be **computed** from other variables, and they can be **reused** anywhere in the program without retyping.
#
# When we load your `team.csv` into Python, every column header becomes a variable Python can work with. Every row becomes a set of values for those variables. Python can then use those variables to write the JSON file that the team page reads.

# %% [markdown]
# ---
#
# ## Part 8 — Generate the Team Page
#
# The script `generate_team_json.py` reads your `data/team.csv`, sorts it alphabetically by last name, and writes `team_data.json` into the final project folder. The `team.html` page reads that JSON automatically — you never need to touch the HTML.
#
# ### Run the script
#
# 1. Confirm `data/team.csv` (<img src="../lesson_assets/images/vscode/table.svg" alt="CSV icon" width="14">) is saved and fully filled in.
# 2. Click the **Run** button (▶) on the code cell below, or press:
#    - <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> `Shift+Enter`
#    - <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> `Shift+Enter`
#
# ✅ You should see a confirmation listing your team members in alphabetical order.

# %%
# %run generate_team_json.py
# Out:
# ✅ Wrote 2 team members to:
#    /home/joostburgers/Documents/repos/jupyter_hub_codespace/project_5_mapping_emotions/team_data.json
#
#    Joost Burgers — Digital Studies — Coordinator
#    New name Replace with Last Name — Replace with Major — Being fun

# %% [markdown]
# ### View your team page
#
# 1. Open **Explorer** (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">).
# 2. Navigate to `project_5_mapping_emotions/`.
# 3. Right-click `team.html` and choose **Open with → Browser Preview**, or open `http://localhost:8000/project_5_mapping_emotions/team.html` in Simple Browser.
#
# ✅ Your team cards should appear in alphabetical order — with no manual HTML rearranging required.

# %% [markdown]
# ---
#
# ## Part 9 — What Just Happened?
#
# Open `generate_team_json.py` (<img src="../lesson_assets/images/vscode/file-text.svg" alt="File icon" width="14">) in **Explorer** (<img src="../lesson_assets/images/vscode/files.svg" alt="Explorer icon" width="14">) and look at these three key lines:
#
# ```python
# df = pd.read_csv(INPUT_CSV)          # Input: load the spreadsheet
# df = df.sort_values("_last_name")    # Compute: sort the rows
# json.dump(output, f)                 # Output: write the JSON file
# ```
#
# These three lines — **read, transform, write** — are the fundamental pattern of almost everything we will do in this course:
#
# | Step | Name | What it means |
# |---|---|---|
# | Read | **Ingest** | Get data from somewhere into Python |
# | Transform | **Wrangling / Analysis** | Shape or analyze the data |
# | Write | **Output** | Save a result or build a presentation |
#
# In future lessons the data will be thousands of Reddit posts, and the transform step will involve finding locations and measuring sentiment. But the pattern — and Python’s role in it — is exactly the same.
#
# ---
#
# ### Discussion Questions
#
# 1. If a team member changes their GitHub username, how do you update the website now, compared to before?
# 2. The script sorts by last name automatically. What would you change in `team.csv` to get a different sort order?
# 3. The final project’s `team.html` never changes — only `team_data.json` does. Why is this a better design?
# 4. Where else in everyday life do you see “data” separated from “presentation”? (Think: music streaming apps, online stores, social media feeds.)
